# %%
import pandas as pd

df = pd.read_csv("../data/raw/boxscore.csv")

df.head(5)
# Out:
#    game_id          teamName          playerName     MP FG FGA 3P 3PA FT FTA  \
# 0        1  Sacramento Kings  Corliss Williamson  37:20  7  11  0   0  0   0
# 1        1  Sacramento Kings      Mitch Richmond  32:00  6  12  1   4  1   1
# 2        1  Sacramento Kings      Olden Polynice  31:34  0   4  0   0  1   4
# 3        1  Sacramento Kings  Mahmoud Abdul-Rauf  29:27  7  13  1   2  2   2
# 4        1  Sacramento Kings         Brian Grant  25:13  3  11  0   0  2   2
#
#    ... DRB TRB AST STL BLK TOV PF PTS  +/- isStarter
# 0  ...   3   4   4   1   1   4  5  14   -2         1
# 1  ...   5   5   3   1   2   3  1  14  -12         1
# 2  ...   5   7   3   1   0   4  3   1  -12         1
# 3  ...   2   2   5   1   1   2  2  17   -7         1
# 4  ...   5   6   0   0   2   1  2   8   -7         1
#
# [5 rows x 21 columns]
